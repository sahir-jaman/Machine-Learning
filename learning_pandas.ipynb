# %% [markdown]
# # pandas input

# %%
import pandas as pd

# %%
data = {
    "Students": ["Sahir","Rahim","Ramim","Siam","Muhammad","Rakib","Shakil","Boogs"],
    "Roll num": [1,5,3,8,9,"Nan",18,"Nan"],
}

myData = pd.DataFrame(data)
myData
# Out:
#    Students Roll num
# 0     Sahir        1
# 1     Rahim        5
# 2     Ramim        3
# 3      Siam        8
# 4  Muhammad        9
# 5     Rakib      Nan
# 6    Shakil       18
# 7     Boogs      Nan

# %% [markdown]
# ## Now Lets Remove Null values from a csv file

# %%
model = pd.read_csv("music.csv")  # Here is two null values at Row 0,4
model
# Out:
#     age  gender   songType
# 0    20       1        NaN
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1        NaN
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
myCleanModel = model.dropna()
myCleanModel
# Out:
#     age  gender   songType
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# ## Now lets add vules at place Null

# %%
secondModel = pd.read_csv("music.csv")
secondModel
# Out:
#     age  gender   songType
# 0    20       1        NaN
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1        NaN
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
secondModel.fillna("Sahir_jaman",inplace = True)
secondModel
# Out:
#     age  gender     songType
# 0    20       1  Sahir_jaman
# 1    23       1       HipHop
# 2    25       1       HipHop
# 3    26       1         Jazz
# 4    29       1  Sahir_jaman
# 5    30       1         Jazz
# 6    31       1    Classical
# 7    33       1    Classical
# 8    37       1    Classical
# 9    20       0        Dance
# 10   21       0        Dance
# 11   25       0        Dance
# 12   26       0     Acoustic
# 13   27       0     Acoustic
# 14   30       0     Acoustic
# 15   31       0    Classical
# 16   34       0    Classical
# 17   35       0    Classical
